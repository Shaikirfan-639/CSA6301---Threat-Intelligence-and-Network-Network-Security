# %%
network = {
    "Low": ["Internet"],
    "Sensitive": ["Admin"]
}

source = "Low"
destination = "Sensitive"

if destination in network[source]:
    print("Access Allowed")
else:
    print("Access Blocked - Segmentation")
# Out:
# Access Blocked - Segmentation
