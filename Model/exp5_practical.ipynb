# %%
text = input("Enter report description: ").lower()

if "executive" in text or "business" in text:
    print("Strategic")
elif "tactic" in text or "attack technique" in text:
    print("Tactical")
else:
    print("Operational")
# Out:
# Enter report description: Report prepared for company executives about future cyber risks
# Strategic
